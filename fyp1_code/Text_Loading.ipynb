# %%
import os


class TextFileLoader:
    def __init__(self, folder_path):
        self.folder_path = folder_path

    def load_text_files(self):
        if os.path.exists(self.folder_path) and os.path.isdir(self.folder_path):
            # Get a list of all text files in the folder
            text_files = [file for file in os.listdir(self.folder_path) if file.endswith(".txt")]

            # Iterate through each text file and load its content
            for file_name in text_files:
                file_path = os.path.join(self.folder_path, file_name)

                # Open the file and read its content
                with open(file_path, "r", encoding="utf-8") as file:
                    file_content = file.read()

                # Process the file content as needed (you can customize this part)
                print(f"File: {file_name}")
                print("Content:")
                print(file_content)
                print("-" * 50)

        else:
            print(f"The folder path '{self.folder_path}' is not valid.")

# Example usage:
folder_path = "/media/osama/26D25BC6D25B993F1/Seven Semester/Fyp/LAGAN-main/data/sketches/sketches/text"
loader = TextFileLoader(folder_path)
loader.load_text_files()
# Out:
# File: 00360.txt
# Content:
# this woman has a rectangular face with long hair.
# she has a pair of big wide eyes,with dense thin and flat eyebrows.
# her mouth is thick and wide,with a big long nose and her ears are normal.
# she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 00720.txt
# Content:
# this woman has an inverted triangle face with short hair.
# he has a pair of big wide eyes,with dense thin and arched eyebrows.
# her mouth is thin and wide,with a medium normal nose and her ears are small.
# she hasn’t glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00001.txt
# Content:
# this man has a round face with medium hair.
#  he has a pair of medium normal eyes,with sparse thin and flat eyebrows.
#  his mouth is thin and wide, with a medium long nose and his ears are big.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00002.txt
# Content:
# this man has a rectangular face with medium hair.
#  he has a pair of big wide eyes,with dense thin and arched eyebrows.
#  his mouth is thick and wide, with a big long nose and his ears are normal.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00003.txt
# Content:
# this man has a inverted triangle face with short hair.
#  he has a pair of small normal eyes,with dense thin and flat eyebrows.
#  his mouth is thick and wide, with a medium normal nose and his ears are big.
#  he has glasses and has beard.
#
# --------------------------------------------------
# File: 00004.txt
# Content:
# this man has a round face with short hair.
#  he has a pair of medium narrow eyes,with sparse thick and flat eyebrows.
#  his mouth is thick and narrow, with a small long nose and his ears are normal.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00005.txt
# Content:
# this man has a heart face with short hair.
#  he has a pair of medium normal eyes,with dense thick and flat eyebrows.
#  his mouth is thick and narrow, with a medium short nose and his ears are small.
#  he has glasses and has beard.
#
# --------------------------------------------------
# File: 00006.txt
# Content:
# this man has a round face with medium hair.
#  he has a pair of medium narrow eyes,with dense thick and down eyebrows.
#  his mouth is thick and narrow, with a medium short nose and his ears are big.
#  he has glasses and has beard.
#
# --------------------------------------------------
# File: 00007.txt
# Content:
# this man has a diamond face with medium hair.
#  he has a pair of big wide eyes,with dense thin and arched eyebrows.
#  his mouth is thick and wide, with a medium normal nose and his ears are big.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00008.txt
# Content:
# this man has a oval face with medium hair.
#  he has a pair of small wide eyes,with dense thin and flat eyebrows.
#  his mouth is thick and wide, with a big short nose and his ears are big.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00009.txt
# Content:
# this woman has a rectangular face with long hair.
#  she has a pair of big narrow eyes,with sparse thin and flat eyebrows.
#  her mouth is thin and wide, with a small normal nose and her ears are big.
#  she hasn’t glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00010.txt
# Content:
# this man has a diamond face with medium hair.
#  he has a pair of medium wide eyes,with sparse thin and arched eyebrows.
#  his mouth is thick and wide, with a small normal nose and his ears are big.
#  his hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00011.txt
# Content:
# this man has a rectangular face with medium hair.
#  he has a pair of small normal eyes,with dense thick and flat eyebrows.
#  his mouth is thick and narrow, with a big long nose and his ears are small.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00012.txt
# Content:
# this man has a heart face with medium hair.
#  he has a pair of big normal eyes,with dense thin and arched eyebrows.
#  his mouth is thick and narrow, with a medium long nose and his ears are normal.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00013.txt
# Content:
# this man has a oval face with medium hair.
#  he has a pair of big normal eyes,with dense thick and arched eyebrows.
#  his mouth is thick and narrow, with a medium long nose and his ears are big.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00014.txt
# Content:
# this woman has a square face with long hair.
#  she has a pair of small normal eyes,with dense thin and flat eyebrows.
#  her mouth is thick and wide, with a small long nose and her ears are normal.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00015.txt
# Content:
# this man has a round face with medium hair.
#  he has a pair of medium narrow eyes,with dense thin and arched eyebrows.
#  his mouth is thin and wide, with a medium long nose and his ears are small.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00016.txt
# Content:
# this woman has a triangular face with long hair.
#  she has a pair of medium normal eyes,with dense thin and arched eyebrows.
#  her mouth is thick and narrow, with a small normal nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00017.txt
# Content:
# this woman has a round face with long hair.
#  she has a pair of medium narrow eyes,with sparse thin and arched eyebrows.
#  her mouth is thick and narrow, with a small normal nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00018.txt
# Content:
# this man has a heart face with medium hair.
#  he has a pair of big normal eyes,with dense thick and arched eyebrows.
#  his mouth is thick and wide, with a big long nose and his ears are normal.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00019.txt
# Content:
# this man has a diamond face with medium hair.
#  he has a pair of big normal eyes,with dense thick and flat eyebrows.
#  his mouth is thick and narrow, with a small normal nose and his ears are small.
#  he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 00021.txt
# Content:
# this woman has a heart face with long hair.
#  she has a pair of big normal eyes,with dense thin and arched eyebrows.
#  her mouth is thick and narrow, with a medium normal nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00022.txt
# Content:
# this man has a square face with medium hair.
#  he has a pair of medium normal eyes,with sparse thick and flat eyebrows.
#  his mouth is thick and wide, with a medium long nose and his ears are normal.
#  he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 00023.txt
# Content:
# this man has a rectangular face with medium hair.
#  he has a pair of medium normal eyes,with dense thin and flat eyebrows.
#  his mouth is thick and narrow, with a medium normal nose and his ears are small.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00024.txt
# Content:
# this man has a square face with short hair.
#  he has a pair of medium narrow eyes,with dense thick and arched eyebrows.
#  his mouth is thin and wide, with a medium normal nose and his ears are small.
#  he has glasses and has beard.
#
# --------------------------------------------------
# File: 00025.txt
# Content:
# this woman has a heart face with medium hair.
#  she has a pair of medium normal eyes,with sparse thin and flat eyebrows.
#  her mouth is thick and wide, with a medium normal nose and her ears are small.
#  she has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00026.txt
# Content:
# this woman has a oval face with long hair.
#  she has a pair of big wide eyes,with sparse thin and flat eyebrows.
#  her mouth is thick and narrow, with a small short nose and her ears are small.
#  she has glasses and hasn't beard.
#
# --------------------------------------------------
# File: 00027.txt
# Content:
# this woman has a rectangular face with long hair.
#  she has a pair of medium wide eyes,with dense thin and arched eyebrows.
#  her mouth is thin and wide, with a small short nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00028.txt
# Content:
# this man has a rectangular face with short hair.
#  he has a pair of big wide eyes,with dense thick and flat eyebrows.
#  his mouth is thick and wide, with a small normal nose and his ears are small.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00029.txt
# Content:
# this man has a oval face with short hair.
#  he has a pair of medium wide eyes,with dense thick and down eyebrows.
#  his mouth is thick and wide, with a medium normal nose and his ears are big.
#  he has glasses and has beard.
#
# --------------------------------------------------
# File: 00030.txt
# Content:
# this man has a heart face with medium hair.
#  he has a pair of medium wide eyes,with dense thick and flat eyebrows.
#  his mouth is thin and wide, with a medium long nose and his ears are normal.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00031.txt
# Content:
# this man has a square face with short hair.
#  he has a pair of medium wide eyes,with dense thick and flat eyebrows.
#  his mouth is thick and wide, with a medium normal nose and his ears are big.
#  he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 00032.txt
# Content:
# this woman has a heart face with long hair.
#  she has a pair of medium wide eyes,with dense thin and flat eyebrows.
#  her mouth is thick and wide, with a small normal nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00033.txt
# Content:
# this woman has a round face with long hair.
#  she has a pair of medium wide eyes,with sparse thin and flat eyebrows.
#  her mouth is thin and narrow, with a small long nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00034.txt
# Content:
# this man has a heart face with short hair.
#  he has a pair of big normal eyes,with dense thick and arched eyebrows.
#  his mouth is thin and wide, with a small normal nose and his ears are normal.
#  he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 00035.txt
# Content:
# this woman has a rectangular face with long hair.
#  she has a pair of big normal eyes,with dense thin and arched eyebrows.
#  her mouth is thick and wide, with a small long nose and her ears are small.
#  she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 00036.txt
# Content:
# this woman has a triangular face with long hair.
#  she has a pair of small wide eyes,with sparse thin and arched eyebrows.
#  her mouth is thick and wide, with a medium long nose and her ears are small.
#  she hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 00037.txt
# Content:
# this man has a oval face with medium hair.
#  he has a pair of big normal eyes,with sparse thin and flat eyebrows.
#  his mouth is thick and wide, with a small long nose and his ears are normal.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00038.txt
# Content:
# this woman has a diamond face with long hair.
#  she has a pair of medium normal eyes,with sparse thin and flat eyebrows.
#  her mouth is thick and wide, with a small long nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00039.txt
# Content:
# this man has a round face with medium hair.
#  he has a pair of small wide eyes,with sparse thin and down eyebrows.
#  his mouth is thick and wide, with a small short nose and his ears are small.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00041.txt
# Content:
# this man has a rectangular face with short hair.
#  he has a pair of medium wide eyes,with dense thick and arched eyebrows.
#  his mouth is thick and narrow, with a medium normal nose and his ears are big.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00042.txt
# Content:
# this woman has a diamond face with medium hair.
#  she has a pair of big normal eyes,with dense thin and flat eyebrows.
#  her mouth is thin and wide, with a small long nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00043.txt
# Content:
# this man has a diamond face with medium hair.
#  he has a pair of small wide eyes,with dense thick and down eyebrows.
#  his mouth is thick and wide, with a medium long nose and his ears are normal.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00044.txt
# Content:
# this woman has a round face with medium hair.
#  she has a pair of medium normal eyes,with sparse thin and flat eyebrows.
#  her mouth is thick and wide, with a medium short nose and her ears are normal.
#  she has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00045.txt
# Content:
# this man has a rectangular face with medium hair.
#  he has a pair of medium normal eyes,with dense thick and flat eyebrows.
#  his mouth is thick and wide, with a small long nose and his ears are big.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00046.txt
# Content:
# this woman has a heart face with long hair.
#  she has a pair of big normal eyes,with sparse thin and arched eyebrows.
#  her mouth is thick and narrow, with a medium normal nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00047.txt
# Content:
# this man has a round face with short hair.
#  he has a pair of big normal eyes,with sparse thick and flat eyebrows.
#  his mouth is thin and narrow, with a medium short nose and his ears are small.
#  he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 00048.txt
# Content:
# this woman has a square face with long hair.
#  she has a pair of medium normal eyes,with dense thin and arched eyebrows.
#  her mouth is thick and wide, with a small normal nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00049.txt
# Content:
# this woman has a oval face with long hair.
#  she has a pair of big normal eyes,with sparse thin and arched eyebrows.
#  her mouth is thick and wide, with a small normal nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00050.txt
# Content:
# this man has a square face with medium hair.
#  he has a pair of medium wide eyes,with dense thick and flat eyebrows.
#  his mouth is thick and wide, with a small normal nose and his ears are normal.
#  he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 00051.txt
# Content:
# this man has a heart face with medium hair.
#  he has a pair of big normal eyes,with dense thick and arched eyebrows.
#  his mouth is thick and narrow, with a medium long nose and his ears are small.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00052.txt
# Content:
# this woman has a heart face with long hair.
#  she has a pair of small normal eyes,with sparse thin and flat eyebrows.
#  her mouth is thick and wide, with a medium normal nose and her ears are normal.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00053.txt
# Content:
# this man has a diamond face with short hair.
#  he has a pair of medium wide eyes,with dense thick and down eyebrows.
#  his mouth is thick and wide, with a medium normal nose and his ears are small.
#  he has glasses and has beard.
#
# --------------------------------------------------
# File: 00054.txt
# Content:
# this man has a diamond face with medium hair.
#  he has a pair of small wide eyes,with dense thin and flat eyebrows.
#  his mouth is thin and wide, with a small normal nose and his ears are big.
#  he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 00055.txt
# Content:
# this woman has a square face with long hair.
#  she has a pair of big normal eyes,with dense thin and flat eyebrows.
#  her mouth is thick and wide, with a medium normal nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00056.txt
# Content:
# this man has a round face with short hair.
#  he has a pair of small normal eyes,with dense thick and flat eyebrows.
#  his mouth is thick and wide, with a medium normal nose and his ears are small.
#  he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 00057.txt
# Content:
# this woman has a heart face with long hair.
#  she has a pair of medium narrow eyes,with sparse thin and arched eyebrows.
#  her mouth is thin and narrow, with a medium short nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00058.txt
# Content:
# this man has a square face with medium hair.
#  he has a pair of medium normal eyes,with dense thin and flat eyebrows.
#  his mouth is thin and wide, with a medium short nose and his ears are normal.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00059.txt
# Content:
# this man has a round face with short hair.
#  he has a pair of small wide eyes,with dense thick and flat eyebrows.
#  his mouth is thin and wide, with a medium normal nose and his ears are small.
#  he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 00061.txt
# Content:
# this man has a round face with medium hair.
#  he has a pair of medium wide eyes,with dense thick and flat eyebrows.
#  his mouth is thick and narrow, with a small long nose and his ears are big.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00062.txt
# Content:
# this man has a diamond face with medium hair.
#  he has a pair of medium normal eyes,with sparse thin and flat eyebrows.
#  his mouth is thin and narrow, with a medium normal nose and his ears are small.
#  he has glasses and has beard.
#
# --------------------------------------------------
# File: 00063.txt
# Content:
# this man has a rectangular face with short hair.
#  he has a pair of medium normal eyes,with sparse thin and flat eyebrows.
#  his mouth is thin and wide, with a small normal nose and his ears are big.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00064.txt
# Content:
# this man has a round face with short hair.
#  he has a pair of big normal eyes,with dense thick and arched eyebrows.
#  his mouth is thin and wide, with a medium normal nose and his ears are small.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00065.txt
# Content:
# this man has a diamond face with medium hair.
#  he has a pair of small narrow eyes,with dense thick and flat eyebrows.
#  his mouth is thick and wide, with a medium normal nose and his ears are small.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00066.txt
# Content:
# this man has a square face with short hair.
#  he has a pair of big wide eyes,with sparse thin and arched eyebrows.
#  his mouth is thin and narrow, with a small normal nose and his ears are big.
#  he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 00067.txt
# Content:
# this man has a heart face with medium hair.
#  he has a pair of medium normal eyes,with sparse thin and flat eyebrows.
#  his mouth is thick and narrow, with a medium short nose and his ears are big.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00068.txt
# Content:
# this woman has a diamond face with long hair.
#  she has a pair of medium wide eyes,with dense thin and arched eyebrows.
#  her mouth is thin and wide, with a medium normal nose and her ears are small.
#  she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 00069.txt
# Content:
# this man has a oval face with medium hair.
#  he has a pair of medium wide eyes,with dense thick and flat eyebrows.
#  his mouth is thick and narrow, with a small normal nose and his ears are normal.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00070.txt
# Content:
# this man has a heart face with medium hair.
#  he has a pair of small wide eyes,with sparse thin and arched eyebrows.
#  his mouth is thick and narrow, with a medium normal nose and his ears are small.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00071.txt
# Content:
# this woman has a square face with long hair.
#  she has a pair of small normal eyes,with sparse thin and down eyebrows.
#  her mouth is thin and wide, with a small normal nose and her ears are small.
#  she has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00072.txt
# Content:
# this man has a heart face with short hair.
#  he has a pair of medium normal eyes,with dense thick and flat eyebrows.
#  his mouth is thick and wide, with a big normal nose and his ears are normal.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00073.txt
# Content:
# this man has a heart face with short hair.
#  he has a pair of medium normal eyes,with sparse thin and up eyebrows.
#  his mouth is thin and narrow, with a big short nose and his ears are normal.
#  he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 00074.txt
# Content:
# this woman has a diamond face with long hair.
#  she has a pair of medium narrow eyes,with sparse thin and flat eyebrows.
#  her mouth is thick and narrow, with a medium short nose and her ears are normal.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00075.txt
# Content:
# this man has a square face with medium hair.
#  he has a pair of medium wide eyes,with dense thin and arched eyebrows.
#  his mouth is thick and narrow, with a small short nose and his ears are big.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00076.txt
# Content:
# this woman has a round face with medium hair.
#  she has a pair of medium wide eyes,with sparse thin and down eyebrows.
#  her mouth is thick and narrow, with a big short nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00077.txt
# Content:
# this man has a diamond face with short hair.
#  he has a pair of medium normal eyes,with dense thin and arched eyebrows.
#  his mouth is thick and narrow, with a medium long nose and his ears are small.
#  he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 00078.txt
# Content:
# this man has a diamond face with medium hair.
#  he has a pair of small wide eyes,with dense thick and arched eyebrows.
#  his mouth is thick and wide, with a small normal nose and his ears are big.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00079.txt
# Content:
# this man has a round face with medium hair.
#  he has a pair of medium normal eyes,with dense thick and arched eyebrows.
#  his mouth is thin and narrow, with a big long nose and his ears are big.
#  he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 00081.txt
# Content:
# this woman has a square face with long hair.
#  she has a pair of big normal eyes,with dense thick and flat eyebrows.
#  her mouth is thick and wide, with a medium normal nose and her ears are small.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00082.txt
# Content:
# this woman has a heart face with medium hair.
#  she has a pair of big normal eyes,with dense thin and arched eyebrows.
#  her mouth is thick and narrow, with a small short nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00083.txt
# Content:
# this man has a round face with short hair.
#  he has a pair of medium normal eyes,with dense thick and flat eyebrows.
#  his mouth is thick and wide, with a medium long nose and his ears are small.
#  he has glasses and has beard.
#
# --------------------------------------------------
# File: 00084.txt
# Content:
# this woman has a diamond face with long hair.
#  she has a pair of medium normal eyes,with dense thick and flat eyebrows.
#  her mouth is thin and wide, with a small long nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00085.txt
# Content:
# this man has a rectangular face with medium hair.
#  he has a pair of medium normal eyes,with dense thick and flat eyebrows.
#  his mouth is thick and wide, with a small normal nose and his ears are normal.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00086.txt
# Content:
# this woman has a rectangular face with medium hair.
#  she has a pair of big narrow eyes,with dense thin and flat eyebrows.
#  her mouth is thick and narrow, with a small long nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00087.txt
# Content:
# this man has a heart face with short hair.
#  he has a pair of medium wide eyes,with dense thick and arched eyebrows.
#  his mouth is thick and wide, with a small normal nose and his ears are small.
#  he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 00088.txt
# Content:
# this man has a rectangular face with medium hair.
#  he has a pair of medium normal eyes,with sparse thick and flat eyebrows.
#  his mouth is thin and wide, with a medium normal nose and his ears are normal.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00089.txt
# Content:
# this woman has a heart face with long hair.
#  she has a pair of medium normal eyes,with sparse thin and flat eyebrows.
#  her mouth is thick and wide, with a small normal nose and her ears are normal.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00090.txt
# Content:
# this woman has a oval face with long hair.
#  she has a pair of medium normal eyes,with dense thin and flat eyebrows.
#  her mouth is thick and narrow, with a medium normal nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00091.txt
# Content:
# this man has a round face with medium hair.
#  he has a pair of medium normal eyes,with dense thin and down eyebrows.
#  his mouth is thick and wide, with a medium normal nose and his ears are small.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00092.txt
# Content:
# this man has a heart face with medium hair.
#  he has a pair of medium normal eyes,with dense thick and flat eyebrows.
#  his mouth is thin and wide, with a small long nose and his ears are big.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00093.txt
# Content:
# this man has a heart face with medium hair.
#  he has a pair of medium wide eyes,with dense thick and flat eyebrows.
#  his mouth is thick and wide, with a medium long nose and his ears are big.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00094.txt
# Content:
# this man has a diamond face with medium hair.
#  he has a pair of medium normal eyes,with dense thin and flat eyebrows.
#  his mouth is thick and wide, with a medium normal nose and his ears are normal.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00095.txt
# Content:
# this man has a oval face with medium hair.
#  he has a pair of small normal eyes,with dense thin and flat eyebrows.
#  his mouth is thick and wide, with a medium normal nose and his ears are big.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00096.txt
# Content:
# this man has a diamond face with short hair.
#  he has a pair of medium normal eyes,with sparse thin and flat eyebrows.
#  his mouth is thin and wide, with a medium short nose and his ears are small.
#  he has glasses and has beard.
#
# --------------------------------------------------
# File: 00097.txt
# Content:
# this man has a round face with short hair.
#  he has a pair of small normal eyes,with dense thin and flat eyebrows.
#  his mouth is thick and wide, with a small short nose and his ears are small.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00098.txt
# Content:
# this man has a heart face with medium hair.
#  he has a pair of medium normal eyes,with sparse thick and flat eyebrows.
#  his mouth is thick and wide, with a small long nose and his ears are normal.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00099.txt
# Content:
# this woman has a diamond face with long hair.
#  she has a pair of medium normal eyes,with dense thin and flat eyebrows.
#  her mouth is thick and wide, with a small long nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00020.txt
# Content:
# this man has a rectangular face with medium hair.
#  he has a pair of big normal eyes,with dense thick and arched eyebrows.
#  his mouth is thick and narrow, with a small long nose and his ears are normal.
#  he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 00040.txt
# Content:
# this man has a oval face with short hair.
#  he has a pair of big wide eyes,with sparse thick and arched eyebrows.
#  his mouth is thick and wide, with a small long nose and his ears are normal.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00060.txt
# Content:
# this man has a heart face with short hair.
#  he has a pair of medium wide eyes,with dense thick and flat eyebrows.
#  his mouth is thick and narrow, with a small normal nose and his ears are small.
#  he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 00080.txt
# Content:
# this man has a round face with medium hair.
#  he has a pair of small normal eyes,with dense thick and flat eyebrows.
#  his mouth is thick and wide, with a small short nose and his ears are small.
#  he has glasses and has beard.
#
# --------------------------------------------------
# File: 00100.txt
# Content:
# this woman has a square face with long hair.
#  she has a pair of big normal eyes,with sparse thin and flat eyebrows.
#  her mouth is thick and wide, with a medium long nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00120.txt
# Content:
# this man has a square face with medium hair.
#  he has a pair of small wide eyes,with sparse thin and flat eyebrows.
#  his mouth is thick and wide, with a medium long nose and his ears are normal.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00140.txt
# Content:
# this man has a round face with medium hair.
#  he has a pair of small normal eyes,with sparse thin and flat eyebrows.
#  his mouth is thin and wide, with a medium short nose and his ears are small.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00160.txt
# Content:
# this man has a square face with medium hair.
#  he has a pair of big normal eyes,with sparse thin and down eyebrows.
#  his mouth is thick and wide, with a medium normal nose and his ears are normal.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00180.txt
# Content:
# this woman has a square face with long hair.
#  she has a pair of medium normal eyes, with dense thick and arched eyebrows.
#  her mouth is thick and wide, with a medium normal nose and her ears are normal.
#  she hasn’t glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00200.txt
# Content:
# this man has a rectangular face with short hair.
#  he has a pair of small normal eyes, with dense thick and arched eyebrows.
#  his mouth is thick and wide, with a big normal nose and his ears are normal.
#  he hasn’t glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00220.txt
# Content:
# this man has a oval face with short hair.
#  he has a pair of medium narrow eyes, with dense thick and flat eyebrows.
#  his mouth is thick and narrow, with a small long nose and his ears are normal.
#  he hasn’t glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00240.txt
# Content:
# this woman has a square face with medium hair.
#  she has a pair of small normal eyes, with dense thick and flat eyebrows.
#  her mouth is thick and wide, with a small normal nose and her ears are small.
#  she hasn’t glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00260.txt
# Content:
# this man has a oval face with short hair.
#  he has a pair of medium normal eyes, with dense thin  and flat eyebrows.
#  his mouth is thick and wide, with a small normal nose and his ears are big.
#  he hasn’t glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00280.txt
# Content:
# this man has a oval face with short hair.
#  he has a pair of small normal eyes, with dense thick and arched eyebrows.
#  his mouth is thick and narrow, with a medium normal nose and his ears are big.
#  he hasn’t glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00300.txt
# Content:
# this man has a rectangular face with short hair.
#  he has a pair of small wide eyes, with dense thin  and arched eyebrows.
#  his mouth is thin and narrow, with a big normal nose and his ears are big.
#  he hasn’t glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00320.txt
# Content:
# this man has a oval face with short hair.
#  he has a pair of small wide eyes, with dense thick and flat eyebrows.
#  his mouth is thick and wide, with a small normal nose and his ears are small.
#  he hasn’t glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00340.txt
# Content:
# this woman has a oval face with long hair.
#  she has a pair of medium normal eyes, with dense thin  and arched eyebrows.
#  her mouth is thin and wide, with a big normal nose and her ears are small.
#  she hasn’t glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00101.txt
# Content:
# this man has a heart face with long hair.
#  he has a pair of medium normal eyes,with sparse thick and arched eyebrows.
#  his mouth is thin and wide, with a medium normal nose and his ears are big.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00102.txt
# Content:
# this woman has a triangular face with long hair.
#  she has a pair of medium normal eyes,with dense thin and flat eyebrows.
#  her mouth is thin and wide, with a small long nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00103.txt
# Content:
# this woman has a oval face with medium hair.
#  she has a pair of medium normal eyes,with dense thin and arched eyebrows.
#  her mouth is thin and narrow, with a medium normal nose and her ears are normal.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00104.txt
# Content:
# this man has a square face with short hair.
#  he has a pair of medium normal eyes,with sparse thick and flat eyebrows.
#  his mouth is thick and wide, with a medium normal nose and his ears are big.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00105.txt
# Content:
# this man has a square face with medium hair.
#  he has a pair of small wide eyes,with dense thin and arched eyebrows.
#  his mouth is thin and wide, with a medium normal nose and his ears are normal.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00106.txt
# Content:
# this man has a heart face with medium hair.
#  he has a pair of small wide eyes,with dense thin and flat eyebrows.
#  his mouth is thick and wide, with a small long nose and his ears are normal.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00107.txt
# Content:
# this woman has a oval face with long hair.
#  she has a pair of medium wide eyes,with dense thin and flat eyebrows.
#  her mouth is thick and wide, with a medium long nose and her ears are big.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00108.txt
# Content:
# this man has a square face with medium hair.
#  he has a pair of medium normal eyes,with dense thin and flat eyebrows.
#  his mouth is thick and wide, with a medium long nose and his ears are normal.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00109.txt
# Content:
# this man has a square face with medium hair.
#  he has a pair of medium normal eyes,with dense thick and down eyebrows.
#  his mouth is thick and wide, with a medium long nose and his ears are big.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00110.txt
# Content:
# this man has a rectangular face with medium hair.
#  he has a pair of medium normal eyes,with dense thin and flat eyebrows.
#  his mouth is thick and wide, with a small long nose and his ears are small.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00111.txt
# Content:
# this man has a diamond face with medium hair.
#  he has a pair of small wide eyes,with dense thin and flat eyebrows.
#  his mouth is thick and wide, with a medium long nose and his ears are normal.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00112.txt
# Content:
# this man has a heart face with short hair.
#  he has a pair of small wide eyes,with dense thin and down eyebrows.
#  his mouth is thick and wide, with a medium normal nose and his ears are big.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00113.txt
# Content:
# this man has a triangular face with short hair.
#  he has a pair of medium normal eyes,with sparse thick and flat eyebrows.
#  his mouth is thin and wide, with a big normal nose and his ears are small.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00114.txt
# Content:
# this man has a rectangular face with medium hair.
#  he has a pair of medium normal eyes,with sparse thin and flat eyebrows.
#  his mouth is thick and wide, with a medium normal nose and his ears are small.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00115.txt
# Content:
# this man has a round face with medium hair.
#  he has a pair of small wide eyes,with sparse thin and flat eyebrows.
#  his mouth is thick and wide, with a big normal nose and his ears are small.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00116.txt
# Content:
# this man has a square face with medium hair.
#  he has a pair of small normal eyes,with dense thin and flat eyebrows.
#  his mouth is thick and wide, with a big long nose and his ears are big.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00117.txt
# Content:
# this man has a round face with long hair.
#  he has a pair of big normal eyes,with dense thin and flat eyebrows.
#  his mouth is thin and wide, with a big long nose and his ears are small.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00118.txt
# Content:
# this woman has a oval face with long hair.
#  she has a pair of medium normal eyes,with dense thin and arched eyebrows.
#  her mouth is thick and wide, with a medium normal nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00119.txt
# Content:
# this man has a heart face with medium hair.
#  he has a pair of medium narrow eyes,with sparse thick and flat eyebrows.
#  his mouth is thick and wide, with a medium long nose and his ears are small.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00121.txt
# Content:
# this man has a rectangular face with medium hair.
#  he has a pair of big normal eyes,with dense thick and flat eyebrows.
#  his mouth is thick and wide, with a small long nose and his ears are normal.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00122.txt
# Content:
# this woman has a heart face with long hair.
#  she has a pair of big normal eyes,with dense thin and arched eyebrows.
#  her mouth is thick and narrow, with a medium normal nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00123.txt
# Content:
# this man has a oval face with medium hair.
#  he has a pair of medium normal eyes,with dense thick and flat eyebrows.
#  his mouth is thin and narrow, with a medium normal nose and his ears are big.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00124.txt
# Content:
# this woman has a square face with long hair.
#  she has a pair of medium normal eyes,with dense thick and arched eyebrows.
#  her mouth is thick and wide, with a medium normal nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00125.txt
# Content:
# this man has a diamond face with medium hair.
#  he has a pair of small wide eyes,with sparse thick and flat eyebrows.
#  his mouth is thin and wide, with a medium long nose and his ears are small.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00126.txt
# Content:
# this woman has a diamond face with long hair.
#  she has a pair of medium normal eyes,with dense thin and flat eyebrows.
#  her mouth is thick and wide, with a medium long nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00127.txt
# Content:
# this man has a square face with medium hair.
#  he has a pair of medium wide eyes,with dense thick and flat eyebrows.
#  his mouth is thick and wide, with a medium normal nose and his ears are normal.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00128.txt
# Content:
# this man has a square face with medium hair.
#  he has a pair of medium wide eyes,with sparse thin and flat eyebrows.
#  his mouth is thin and wide, with a small long nose and his ears are normal.
#  he has glasses and has beard.
#
# --------------------------------------------------
# File: 00129.txt
# Content:
# this woman has a triangular face with long hair.
#  she has a pair of small wide eyes,with dense thin and flat eyebrows.
#  her mouth is thin and wide, with a small long nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00130.txt
# Content:
# this woman has a triangular face with long hair.
#  she has a pair of medium normal eyes,with dense thin and down eyebrows.
#  her mouth is thick and wide, with a big long nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00131.txt
# Content:
# this man has a rectangular face with medium hair.
#  he has a pair of medium normal eyes,with dense thick and flat eyebrows.
#  his mouth is thick and wide, with a big normal nose and his ears are big.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00132.txt
# Content:
# this man has a rectangular face with long hair.
#  he has a pair of small wide eyes,with sparse thin and flat eyebrows.
#  his mouth is thick and wide, with a medium normal nose and his ears are small.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00133.txt
# Content:
# this woman has a triangular face with long hair.
#  she has a pair of medium normal eyes,with sparse thin and flat eyebrows.
#  her mouth is thin and wide, with a big normal nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00134.txt
# Content:
# this man has a diamond face with short hair.
#  he has a pair of medium normal eyes,with sparse thin and flat eyebrows.
#  his mouth is thick and wide, with a big long nose and his ears are normal.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00135.txt
# Content:
# this man has a round face with medium hair.
#  he has a pair of medium narrow eyes,with dense thick and flat eyebrows.
#  his mouth is thick and wide, with a big normal nose and his ears are small.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00136.txt
# Content:
# this man has a rectangular face with medium hair.
#  he has a pair of small wide eyes,with dense thin and flat eyebrows.
#  his mouth is thick and wide, with a big long nose and his ears are small.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00137.txt
# Content:
# this woman has a round face with long hair.
#  she has a pair of small normal eyes,with sparse thin and flat eyebrows.
#  her mouth is thick and narrow, with a medium normal nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00138.txt
# Content:
# this man has a heart face with medium hair.
#  he has a pair of medium normal eyes,with dense thick and arched eyebrows.
#  his mouth is thick and narrow, with a medium long nose and his ears are normal.
#  he has glasses and hasn't beard.
#
# --------------------------------------------------
# File: 00139.txt
# Content:
# this man has a rectangular face with medium hair.
#  he has a pair of medium normal eyes,with dense thick and flat eyebrows.
#  his mouth is thick and wide, with a medium long nose and his ears are small.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00141.txt
# Content:
# this man has a round face with medium hair.
#  he has a pair of small normal eyes,with dense thick and arched eyebrows.
#  his mouth is thick and wide, with a medium normal nose and his ears are small.
#  he has glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00142.txt
# Content:
# this man has a square face with medium hair.
#  he has a pair of small normal eyes,with sparse thick and flat eyebrows.
#  his mouth is thick and wide, with a medium normal nose and his ears are big.
#  he has glasses and has beard.
#
# --------------------------------------------------
# File: 00143.txt
# Content:
# this man has a heart face with medium hair.
#  he has a pair of medium normal eyes,with dense thick and arched eyebrows.
#  his mouth is thick and wide, with a medium short nose and his ears are big.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00144.txt
# Content:
# this man has a square face with medium hair.
# ...
#  he has a pair of medium normal eyes,with dense thin and arched eyebrows.
#  his mouth is thin and wide, with a big normal nose and his ears are small.
#  he hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 00980.txt
# Content:
# this woman has a square face with long hair.
#  she has a pair of medium normal eyes,with dense thin and arched eyebrows.
#  her mouth is thick and wide, with a medium normal nose and her ears are small.
#  she hasn't glasses and hasn’t beard.
#
# --------------------------------------------------
# File: 01000.txt
# Content:
# this man has a square face with short hair.
# he has a pair of medium normal eyes,with sparse thick and arched eyebrows.
# he mouth is thin and wide,with a medium normal nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01016.txt
# Content:
# this man has a square face with short hair.
# he has a pair of medium normal eyes,with dense thick and arched eyebrows.
# he mouth is thick and narrow,with a medium normal nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01036.txt
# Content:
# this woman has a square face with long hair.
# she has a pair of small normal eyes,with dense thin and arched eyebrows.
# her mouth is thick and wide,with a small normal nose and she ears are small.
# she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01056.txt
# Content:
# this man has a inverted triangle face with short hair.
# he has a pair of small narrow eyes,with dense thick and arched eyebrows.
# his mouth is thick and wide,with a medium normal nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01076.txt
# Content:
# this man has a rectangular face with short hair.
# he has a pair of medium normal eyes,with dense thick and arched eyebrows.
# his mouth is thin and wide,with a medium normal nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01096.txt
# Content:
# this woman has a square face with medium hair.
# she has a pair of medium normal eyes,with dense thin and arched eyebrows.
# her mouth is thick and narrow,with a medium normal nose and she ears are small.
# she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01116.txt
# Content:
# this woman has a square face with long hair.
# she has a pair of medium normal eyes,with dense thin and arched eyebrows.
# her mouth is thin and wide,with a medium normal nose and she ears are small.
# she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01097.txt
# Content:
# this woman has a square face with short hair.
# she has a pair of medium normal eyes,with sparse thin and arched eyebrows.
# her mouth is thick and wide,with a medium normal nose and she ears are small.
# she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01098.txt
# Content:
# this woman has a oval face with short hair.
# she has a pair of medium normal eyes,with sparse thin and arched eyebrows.
# her mouth is thick and wide,with a big short nose and she ears are small.
# she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01099.txt
# Content:
# this woman has a square face with medium hair.
# she has a pair of small normal eyes,with dense thin and arched eyebrows.
# her mouth is thick and wide,with a medium normal nose and she ears are small.
# she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01100.txt
# Content:
# this man has a rectangular face with long hair.
# he has a pair of medium normal eyes,with dense thick and arched eyebrows.
# his mouth is thin and wide,with a medium normal nose and he ears are small.
# he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 01101.txt
# Content:
# this woman has a oval face with short hair.
# she has a pair of medium normal eyes,with dense thin and arched eyebrows.
# her mouth is thick and wide,with a medium short nose and she ears are small.
# she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01102.txt
# Content:
# this man has a round face with short hair.
# he has a pair of small narrow eyes,with sparse thick and arched eyebrows.
# his mouth is thick and wide,with a medium normal nose and he ears are small.
# he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 01103.txt
# Content:
# this man has a rectangular face with medium hair.
# he has a pair of small normal eyes,with sparse thin and arched eyebrows.
# his mouth is thick and wide,with a medium short nose and he ears are small.
# he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 01104.txt
# Content:
# this man has a oval face with short hair.
# he has a pair of medium wide eyes,with dense thick and arched eyebrows.
# his mouth is thin and wide,with a medium normal nose and he ears are big.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01105.txt
# Content:
# this man has a oval face with medium hair.
# he has a pair of small narrow eyes,with dense thick and arched eyebrows.
# his mouth is thin and wide,with a medium normal nose and he ears are big.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01106.txt
# Content:
# this woman has a oval face with medium hair.
# she has a pair of medium normal eyes,with dense thin and arched eyebrows.
# her mouth is thick and narrow,with a medium normal nose and she ears are small.
# she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01107.txt
# Content:
# this man has a square face with long hair.
# he has a pair of small normal eyes,with dense thick and arched eyebrows.
# his mouth is thin and wide,with a medium normal nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01108.txt
# Content:
# this woman has a rectangular face with short hair.
# she has a pair of medium narrow eyes,with dense thin and arched eyebrows.
# her mouth is thin and wide,with a small short nose and she ears are small.
# she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01109.txt
# Content:
# this woman has a oval face with short hair.
# she has a pair of medium normal eyes,with dense thin and arched eyebrows.
# her mouth is thin and wide,with a medium normal nose and she ears are small.
# she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01110.txt
# Content:
# this man has a square face with long hair.
# he has a pair of small normal eyes,with sparse thin and arched eyebrows.
# his mouth is thin and wide,with a small short nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01111.txt
# Content:
# this woman has a rectangular face with short hair.
# she has a pair of small normal eyes,with dense thick and arched eyebrows.
# her mouth is thin and wide,with a medium normal nose and she ears are small.
# she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01112.txt
# Content:
# this man has a rectangular face with short hair.
# he has a pair of medium wide eyes,with dense thick and arched eyebrows.
# his mouth is thin and wide,with a small short nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01113.txt
# Content:
# this woman has a rectangular face with long hair.
# she has a pair of small normal eyes,with dense thin and arched eyebrows.
# her mouth is thin and wide,with a small short nose and she ears are small.
# she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01114.txt
# Content:
# this man has a oval face with short hair.
# he has a pair of small normal eyes,with sparse thin and arched eyebrows.
# his mouth is thin and wide,with a medium normal nose and he ears are small.
# he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 01115.txt
# Content:
# this man has a oval face with short hair.
# he has a pair of small wide eyes,with dense thick and flat eyebrows.
# his mouth is thick and wide,with a big short nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01117.txt
# Content:
# this man has a oval face with short hair.
# he has a pair of medium normal eyes,with dense thin and arched eyebrows.
# his mouth is thin and wide,with a medium normal nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01118.txt
# Content:
# this man has a square face with medium hair.
# he has a pair of medium normal eyes,with dense thick and flat eyebrows.
# his mouth is thin and narrow,with a medium normal nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01119.txt
# Content:
# this man has a rectangular face with short hair.
# he has a pair of small normal eyes,with dense thick and arched eyebrows.
# his mouth is thin and wide,with a medium long nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01120.txt
# Content:
# this man has a oval face with medium hair.
# he has a pair of medium normal eyes,with dense thick and arched eyebrows.
# his mouth is thin and wide,with a medium normal nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01121.txt
# Content:
# this woman has a square face with long hair.
# she has a pair of small normal eyes,with dense thick and arched eyebrows.
# her mouth is thin and wide,with a medium long nose and she ears are small.
# she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01122.txt
# Content:
# this man has a rectangular face with short hair.
# he has a pair of small normal eyes,with dense thick and arched eyebrows.
# his mouth is thin and wide,with a medium normal nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01123.txt
# Content:
# this man has a rectangular face with short hair.
# he has a pair of medium normal eyes,with sparse thick and arched eyebrows.
# his mouth is thick and wide,with a medium normal nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01124.txt
# Content:
# this woman has a square face with short hair.
# she has a pair of big normal eyes,with sparse thick and arched eyebrows.
# her mouth is thick and narrow,with a medium normal nose and she ears are small.
# she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01125.txt
# Content:
# this woman has a round face with short hair.
# she has a pair of small normal eyes,with dense thin and arched eyebrows.
# her mouth is thick and wide,with a big  short nose and she ears are small.
# she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01126.txt
# Content:
# this man has a round face with medium hair.
# he has a pair of medium normal eyes,with dense thin and arched eyebrows.
# his mouth is thick and wide,with a medium normal nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01127.txt
# Content:
# this man has a oval face with short hair.
# he has a pair of medium normal eyes,with sparse thin and arched eyebrows.
# his mouth is thick and wide,with a medium normal nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01128.txt
# Content:
# this man has a square face with short hair.
# he has a pair of small normal eyes,with sparse thick and arched eyebrows.
# his mouth is thick and wide,with a medium short nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01129.txt
# Content:
# this woman has a square face with long hair.
# she has a pair of small narrow eyes,with dense thin and arched eyebrows.
# her mouth is thin and narrow,with a medium normal nose and she ears are small.
# she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01130.txt
# Content:
# this woman has a square face with long hair.
# she has a pair of medium normal eyes,with dense thin and arched eyebrows.
# her mouth is thin and wide,with a medium short nose and she ears are small.
# she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01131.txt
# Content:
# this man has a oval face with short hair.
# he has a pair of small narrow eyes,with sparse thick and arched eyebrows.
# his mouth is thick and wide,with a big normal nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01132.txt
# Content:
# this woman has a square face with medium hair.
# she has a pair of medium normal eyes,with dense thin and flat eyebrows.
# her mouth is thin and wide,with a medium normal nose and she ears are small.
# she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01133.txt
# Content:
# this man has a rectangular face with short hair.
# he has a pair of medium wide eyes,with dense thick and flat eyebrows.
# his mouth is thick and wide,with a medium normal nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01134.txt
# Content:
# this man has a square face with short hair.
# he has a pair of small narrow eyes,with dense thick and flat eyebrows.
# his mouth is thick and narrow,with a big normal nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01135.txt
# Content:
# this man has a round face with short hair.
# he has a pair of small normal eyes,with sparse thin and arched eyebrows.
# his mouth is thick and narrow,with a medium normal nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01136.txt
# Content:
# this man has a square face with short hair.
# he has a pair of medium normal eyes,with dense thick and arched eyebrows.
# his mouth is thick and wide,with a medium normal nose and he ears are small.
# he hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01137.txt
# Content:
# this man has a rectangular face with short hair.
# he has a pair of small narrow eyes,with dense thick and arched eyebrows.
# his mouth is thin and wide,with a medium normal nose and he ears are small.
# he hasn't glasses and has beard.
#
# --------------------------------------------------
# File: 01138.txt
# Content:
# this woman has a rectangular face with long hair.
# she has a pair of medium normal eyes,with dense thin and arched eyebrows.
# her mouth is thin and wide,with a medium normal nose and she ears are small.
# she hasn't glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01139.txt
# Content:
# this man has a rectangular face with short hair.
# he has a pair of small narrow eyes,with dense thick and flat eyebrows.
# his mouth is thin and wide,with a medium normal nose and he ears are small.
# he has glasses and hasn't beard.
#
# --------------------------------------------------
# File: 01140.txt
# Content:
# this man has a rectangular face with short hair.
# he has a pair of small narrow eyes,with dense thick and flat eyebrows.
# his mouth is thin and wide,with a medium normal nose and he ears are small.
# he has glasses and hasn't beard.
#
# --------------------------------------------------
